# %%
import joblib
import pandas as pd
#load your model for further usage
a = joblib.load("logistic.pkl")

# %%
results = pd.DataFrame(a.cv_results_)

# %%
results.drop
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.021854      0.002001         0.000000        0.000000
# 1         1.715393      0.059771         0.002911        0.000435
# 2         0.029464      0.003964         0.000000        0.000000
# 3         0.028003      0.002889         0.000000        0.000000
# 4         0.026491      0.002422         0.000000        0.000000
# ..             ...           ...              ...             ...
# 787       0.031687      0.003443         0.000000        0.000000
# 788       0.032086      0.005502         0.000000        0.000000
# 789       0.033175      0.003694         0.000000        0.000000
# 790       0.039164      0.004289         0.000000        0.000000
# 791       0.035760      0.004913         0.000000        0.000000
#
#                                       param_classifier param_classifier__C  \
# 0    LogisticRegression(C=0.01, l1_ratio=0.25, max_...             0.00001
# ...

# %%
result_2 = results.loc[results["param_classifier__solver"] =="liblinear" ]

# %%
result2 = result_2.dropna()

# %%
result2
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1         1.715393      0.059771         0.002911        0.000435
# 7         0.219754      0.052164         0.003707        0.000757
# 25        0.104199      0.009485         0.002754        0.000604
# 31        0.226669      0.020782         0.004162        0.001354
# 49        0.140666      0.015442         0.003070        0.000786
# ..             ...           ...              ...             ...
# 727       2.694221      0.240283         0.003258        0.000714
# 745       1.480170      0.364483         0.002650        0.000768
# 751       1.701701      0.170156         0.004159        0.003493
# 769       1.987359      0.881740         0.002659        0.000752
# 775       2.181189      0.906004         0.002503        0.000498
#
#                                       param_classifier param_classifier__C  \
# 1    LogisticRegression(C=0.01, l1_ratio=0.25, max_...             0.00001
# ...

# %%
results.sort_values('rank_test_score')["param_classifier__penalty"][0:50].value_counts()
# Out:
# l2            36
# l1             9
# elasticnet     5
# Name: param_classifier__penalty, dtype: int64
